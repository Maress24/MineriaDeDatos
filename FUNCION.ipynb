# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# %%
df_peliculas = pd.read_csv('DATA_LIMPIO.csv')

# %%
df_fun = df_peliculas.groupby(["Genero"]).agg({'Ventas': ['sum', 'count', 'mean', 'min', 'max']})

# %%
df_fun = df_fun.reset_index()

# %%
df_fun.columns = ['Genero', 'Suma_Total_Ventas', 'Conteo_Genero', 'Promedio_Ventas', 'Ventas_Minima', 'Ventas_Maximas']

# %%
df_fun
# Out:
#           Genero  Suma_Total_Ventas  Conteo_Genero  Promedio_Ventas  \
# 0       Aventura             916474            179      5119.966480
# 1         Belico              90821             18      5045.611111
# 2       Comedia             5442264           1089      4997.487603
# 3   Cortometraje               5848              1      5848.000000
# 4         Crimen            1354125            261      5188.218391
# 5     Documental            1922012            400      4805.030000
# 6       Fantasia             105535             25      4221.400000
# 7      Fantasia              157942             30      5264.733333
# 8         Guerra              90082             23      3916.608696
# 9       Historia             204544             38      5382.736842
# 10        Horror              60624              9      6736.000000
# 11       Musical             501717            109      4602.908257
# 12      Suspenso              99769             23      4337.782609
# 13        Terror            1346289            276      4877.858696
# 14       Western             367383             70      5248.328571
#
#     Ventas_Minima  Ventas_Maximas
# 0              50            9868
# 1             335            9547
# 2              12            9991
# 3            5848            5848
# 4              53            9973
# 5               3            9988
# 6             612            9831
# 7             107            9751
# 8              35            9694
# 9              53            9733
# 10            961            9266
# 11             16            9940
# 12             71            9537
# 13             11            9999
# 14             62            9806
