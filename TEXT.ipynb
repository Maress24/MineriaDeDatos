# %%
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt

# %%
def open_file(path: str) -> str:
    content = ""
    with open(path, "r") as f:
        content = f.readlines()
    return " ".join(content)

all_words = ""
frase = open_file("IG.txt") 
palabras = frase.rstrip().split(" ")
Counter(" ".join(palabras).split()).most_common(10)
# Out:
# [('y', 17),
#  ('de', 15),
#  ('que', 14),
#  ('me', 12),
#  ('el', 11),
#  ('a', 11),
#  ('yo', 9),
#  ('mi', 9),
#  ('la', 7),
#  ('un', 7)]

# %%
for arg in palabras:
    tokens = arg.split()
    all_words += " ".join(tokens) + " "

print(all_words)
# Out:
#  la neta es que me cansa demasiado el siempre estar en donde mismo, no ver avances, mejoras o inclusive ligeros cambios yo solo quiero un plan asÃ­ amo TETEO DE ANUEL con toda el alma i'm just a girl (quiero tener el pelo largo y corto a la vez) toda tonta pq abrÃ­ el mensaje Ay no, se me cayÃ³ mi tote! Cada vez que me entero de algo que me hicieron en mi pasado, que no sabia, me hace darme cuenta de lo kk que pueden ser las personas, me hace sentir que todo lo que hice fue en vano, y eso hace que yo ya no pueda expresarme ni dar nada por miedo a recibir el mismo trato :( Con este clima solo dan ganas de ver pelÃ­culas y estar acostado a que biennn me caigo de veras Hoy simplemente se juntÃ³ todo :/ Llegue a un lugar donde me siento tan cÃ³modo y lleno Me da tristeza pensar en el "asÃ­ tendrÃ¡ que ser" me toca romantizar estas Ãºltimas 2 semanas del semestre para poder sobrevivir la cama es la nave, y nos fuimos de viaje Al tiro con el seÃ±or de los picosâ€¦ mi amiga: voy a verme con un chico y le dirÃ© a mi mama q estarÃ© contigo oye m disculpas por ser tan intensa? es que contigo si quiero hablar "solo es un viaje de dos dÃ­as" bueno ya sabes donde vivo por si me quieres ir a pedir disculpas a las 3am pedo y con mariachi kiero unos bonneless, un dairy queen, un cold coffee, unas fresas con crema, y a ti siento un vacÃ­o, como q me falta comprar ropa yo y mi corazÃ³n de pollo no podemos con la vida mi caja de recuerdos y yo cuando: acabo de ver el pago para no generar intereses de mi tarjeta Coquito y yo tenemos noche de pelÃ­culas. Me pidiÃ³ ver la de Legalmente Rubia porque le gusta la actuaciÃ³n del perrito homosexual. Coquito y yo somos uno mismo  : yo se que los tiempos de Dios son perfectos pero como quisiera formar personas de otra manera; ya me informaron que el kevinkaarl y yo ahora traemos el mismo look QuÃ© fluya? Que fluya el agua, a mÃ­ dÃ©jeme las cosas claras Listo karma, ya te paguÃ© hasta las que te debÃ­a mi papÃ¡, ya suÃ©ltame. guarda silencio mi vida yo solo quiero estar asÃ­ y amar asÃ­ y ser amada si y cuidar asÃ­ y ser

# %%
wordcloud = WordCloud(
    background_color="white",
    min_font_size=5,
    contour_color='steelblue',
    contour_width=1, 
    colormap='viridis', 
).generate(all_words)

# %%
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
